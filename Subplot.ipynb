# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('D:/IRDE/frame.jpg')

dst = cv2.fastNlMeansDenoisingColored(img,None)

plt.subplot(432),plt.imshow(img)
plt.subplot(288),plt.imshow(dst)
plt.show()
